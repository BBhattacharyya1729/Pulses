# %%
import numpy as np
import matplotlib.pyplot as plt
import qctrlvisualizer as qv

import boulderopal as bo
bo.cloud.set_organization("andrew-goldschmidts-team")
plt.style.use(qv.get_qctrl_style())

colors = {
    "Primitive": "black",
    "Optimized": qv.QCTRL_STYLE_COLORS[0],
    "Robust": qv.QCTRL_STYLE_COLORS[1]
}
# Out:
# Boulder Opal client update available.
# Latest version is 1.1.1, you have 1.1.0.
# Visit https://docs.q-ctrl.com/boulder-opal/changelog for the latest product updates.

# %%
###Qubit Dimension, we start with 2
dim=3

a = np.diag(np.sqrt(np.arange(1, dim)), 1) #single annhilation op
ad = a.T

a0 = np.kron(a,np.eye(dim,dtype=complex))
ad0 = np.kron(ad,np.eye(dim,dtype=complex))
a1 = np.kron(np.eye(dim,dtype=complex),a)
ad1 = np.kron(np.eye(dim,dtype=complex),ad)

# %%
X=np.eye(dim,dtype=complex)
Y=np.eye(dim,dtype=complex)
X[:2,:2] = np.array([[0,1],[1,0]])
Y[:2,:2] = np.array([[0,-1j],[1j,0]])

X0=np.kron(X,np.eye(dim,dtype=complex))
Y0=np.kron(Y,np.eye(dim,dtype=complex))
X1=np.kron(np.eye(dim,dtype=complex),X)
Y1=np.kron(np.eye(dim,dtype=complex),Y)

from scipy.linalg import expm

def excitation(theta):
    return expm(1j * theta/2 * (X0@ Y1 - Y0 @ X1))

# %%
drive_max = 200 * 2 * np.pi * 1e6  # Hz
duration = 0.4e-6  # s

# %%
def scheme_optimization(segment_count,target,initial):
    graph = bo.Graph()
    
    drive0x = graph.real_optimizable_pwc_signal(
            segment_count=segment_count,
            duration=duration,
            maximum=drive_max,
            minimum=-drive_max,
            initial_values=initial["drive0x"],
            name="drive0x",
        )
    
    drive0y = graph.real_optimizable_pwc_signal(
            segment_count=segment_count,
            duration=duration,
            maximum=drive_max,
            minimum=-drive_max,
            initial_values=initial["drive0y"],
            name="drive0y",
        )
    
    
    drive1x  = graph.real_optimizable_pwc_signal(
            segment_count=segment_count,
            duration=duration,
            maximum=drive_max,
            minimum=-drive_max,
            initial_values=initial["drive1x"],
            name="drive1x",
        )
    
    
    drive1y  = graph.real_optimizable_pwc_signal(
            segment_count=segment_count,
            duration=duration,
            maximum=drive_max,
            minimum=-drive_max,
            initial_values=initial["drive1y"],
            name="drive1y",
        )
    
    
    delta0 = graph.real_optimizable_pwc_signal(
            segment_count=segment_count,
            duration=duration,
            maximum=drive_max,
            minimum=-drive_max,
            initial_values=initial["delta0"],
            name="delta0",
        )
    
        
    delta1 = graph.real_optimizable_pwc_signal(
            segment_count=segment_count,
            duration=duration,
            maximum=drive_max,
            minimum=-drive_max,
            initial_values=initial["delta1"],
            name="delta1",
        )
    
    J = graph.real_optimizable_pwc_signal(
            segment_count=segment_count,
            duration=duration,
            maximum=drive_max,
            minimum=-drive_max,
            initial_values=initial["J"],
            name="J",
        )

    control_hamiltonian = (
        delta0 * (ad0 @ a0) + 
        delta1 * (ad1 @ a1) +
        drive0x * (a0+ad0) +
        drive0y * 1j * (a0-ad0) +
        drive1x * (a1+ad1) +
        drive1y * 1j * (a1-ad1) +
        J * (ad0 @a1 +a0 @ ad1)
    )
    
    infidelity = graph.infidelity_pwc(
        hamiltonian=control_hamiltonian,
        target=graph.target(operator=target),
        name="infidelity",
    )
    
    return bo.run_optimization(
        graph=graph,
        optimization_count=1,
        cost_node_name="infidelity",
        output_node_names=[
            "infidelity",
            "delta0",
            "delta1",
            "drive0x",
            "drive0y",
            "drive1x",
            "drive1y",
            "J"
        ],
    )

# %%
pulse_names = ["delta0","delta1","drive0x","drive0y","drive1x","drive1y","J"]

# %%
def interpolate(theta,x,coefficients):
    data = {}
    for i in pulse_names:
        data[i]=scipy.interpolate.interp1d(x=x,y=np.array([p[i] for p in coefficients]),axis=0)(theta)
    return data

# %%
initializations = []
fidelities=[]
for theta in np.linspace(0,2*np.pi,20):
    if(theta==0):
        initial = {i:None for i in pulse_names}
    else:
        initial=initializations[-1]
    optimization=scheme_optimization(20,excitation(theta),initial)
    d={i:optimization['output'][i]['values'] for i in optimization['output']if('values' in optimization['output'][i])}
    fidelities.append(optimization['cost'])
    initializations.append(d)
# Out:
# Your task (action_id="1864717") is queued.
# Your task (action_id="1864717") has completed.
# Your task (action_id="1864718") has started.
# Your task (action_id="1864718") has completed.
# Your task (action_id="1864719") has started.
# Your task (action_id="1864719") has completed.
# Your task (action_id="1864720") has started.
# Your task (action_id="1864720") has completed.
# Your task (action_id="1864721") has started.
# Your task (action_id="1864721") has completed.
# Your task (action_id="1864722") has started.
# Your task (action_id="1864722") has completed.
# Your task (action_id="1864723") has started.
# Your task (action_id="1864723") has completed.
# Your task (action_id="1864724") has started.
# Your task (action_id="1864724") has completed.
# Your task (action_id="1864725") has started.
# Your task (action_id="1864725") has completed.
# Your task (action_id="1864726") has started.
# Your task (action_id="1864726") has completed.
# Your task (action_id="1864727") has started.
# Your task (action_id="1864727") has completed.
# Your task (action_id="1864728") has started.
# Your task (action_id="1864728") has completed.
# Your task (action_id="1864729") is queued.
# Your task (action_id="1864729") has completed.
# Your task (action_id="1864730") has started.
# Your task (action_id="1864730") has completed.
# Your task (action_id="1864731") has started.
# Your task (action_id="1864731") has completed.
# Your task (action_id="1864732") has started.
# Your task (action_id="1864732") has completed.
# Your task (action_id="1864733") has started.
# Your task (action_id="1864733") has completed.
# Your task (action_id="1864734") has started.
# Your task (action_id="1864734") has completed.
# Your task (action_id="1864735") is queued.
# Your task (action_id="1864735") has completed.
# Your task (action_id="1864736") has started.
# Your task (action_id="1864736") has completed.

# %%
def simulate(data,target):
    graph = bo.Graph()
    
    drive0x = graph.pwc_signal(
            data['drive0x'], duration, name='drive0x'
        )
    
    drive0y = graph.pwc_signal(
            data['drive0y'], duration, name='drive0y'
        )
    
    
    drive1x = graph.pwc_signal(
            data['drive1x'], duration, name='drive1x'
        )
    
    
    drive1y = graph.pwc_signal(
            data['drive1y'], duration, name='drive1y'
        )
    
    
    delta0 = graph.pwc_signal(
            data['delta0'], duration, name='delta0'
        )
    
        
    delta1 = graph.pwc_signal(
            data['delta1'], duration, name='delta1'
        )
    
    J  = graph.pwc_signal(
            data['J'], duration, name='J'
        )
    
    control_hamiltonian = (
        delta0 * (ad0 @ a0) + 
        delta1 * (ad1 @ a1) +
        drive0x * (a0+ad0) +
        drive0y * 1j * (a0-ad0) +
        drive1x * (a1+ad1) +
        drive1y * 1j * (a1-ad1) +
        J * (ad0 @a1 +a0 @ ad1)
    )
    
    infidelity = graph.infidelity_pwc(
        hamiltonian=control_hamiltonian,
        target=graph.target(operator=target),
        name="infidelity",
    )
    
    graph_result = bo.execute_graph(graph = graph, output_node_names = ["infidelity"])
    return graph_result

# %%
fidelities=[]
import scipy
for theta in np.linspace(0,2*np.pi,100):
    initial=interpolate(theta,np.linspace(0,2*np.pi,20),initializations)
    simulation=simulate(initial,excitation(theta))
    fidelities.append(simulation['output']['infidelity']['value'])
# Out:
# Your task (action_id="1864737") has completed.
# Your task (action_id="1864738") has completed.
# Your task (action_id="1864739") has started.
# Your task (action_id="1864739") has completed.
# Your task (action_id="1864740") has completed.
# Your task (action_id="1864741") has completed.
# Your task (action_id="1864742") has completed.
# Your task (action_id="1864743") has completed.
# Your task (action_id="1864744") has started.
# Your task (action_id="1864744") has completed.
# Your task (action_id="1864745") has completed.
# Your task (action_id="1864746") has completed.
# Your task (action_id="1864747") is queued.
# Your task (action_id="1864747") has started.
# Your task (action_id="1864747") has completed.
# Your task (action_id="1864748") has completed.
# Your task (action_id="1864749") has started.
# Your task (action_id="1864749") has completed.
# Your task (action_id="1864750") has completed.
# Your task (action_id="1864751") has completed.
# Your task (action_id="1864752") has completed.
# Your task (action_id="1864753") has completed.
# Your task (action_id="1864754") has started.
# Your task (action_id="1864754") has completed.
# Your task (action_id="1864755") has completed.
# Your task (action_id="1864756") has completed.
# Your task (action_id="1864757") has completed.
# Your task (action_id="1864758") has completed.
# Your task (action_id="1864759") has started.
# Your task (action_id="1864759") has completed.
# Your task (action_id="1864760") has completed.
# Your task (action_id="1864761") has completed.
# Your task (action_id="1864762") has completed.
# Your task (action_id="1864763") has completed.
# Your task (action_id="1864764") has started.
# Your task (action_id="1864764") has completed.
# Your task (action_id="1864765") has completed.
# Your task (action_id="1864766") has completed.
# Your task (action_id="1864767") has completed.
# Your task (action_id="1864768") has completed.
# Your task (action_id="1864769") has started.
# Your task (action_id="1864769") has completed.
# Your task (action_id="1864770") has completed.
# Your task (action_id="1864771") has completed.
# Your task (action_id="1864772") has completed.
# Your task (action_id="1864773") has completed.
# Your task (action_id="1864774") has started.
# Your task (action_id="1864774") has completed.
# Your task (action_id="1864775") has completed.
# Your task (action_id="1864776") has completed.
# Your task (action_id="1864777") has completed.
# Your task (action_id="1864778") has completed.
# Your task (action_id="1864779") has started.
# Your task (action_id="1864779") has completed.
# Your task (action_id="1864780") has completed.
# Your task (action_id="1864781") has completed.
# Your task (action_id="1864782") is queued.
# Your task (action_id="1864782") has completed.
# Your task (action_id="1864783") has completed.
# Your task (action_id="1864784") has started.
# Your task (action_id="1864784") has completed.
# Your task (action_id="1864785") has completed.
# Your task (action_id="1864786") has completed.
# Your task (action_id="1864787") is queued.
# Your task (action_id="1864787") has completed.
# Your task (action_id="1864788") has completed.
# Your task (action_id="1864789") has started.
# Your task (action_id="1864789") has completed.
# Your task (action_id="1864790") has completed.
# Your task (action_id="1864791") has completed.
# Your task (action_id="1864792") has completed.
# Your task (action_id="1864793") has completed.
# Your task (action_id="1864794") has started.
# Your task (action_id="1864794") has completed.
# Your task (action_id="1864795") has completed.
# Your task (action_id="1864796") has completed.
# Your task (action_id="1864797") has completed.
# Your task (action_id="1864798") has completed.
# Your task (action_id="1864799") has started.
# Your task (action_id="1864799") has completed.
# Your task (action_id="1864800") has completed.
# Your task (action_id="1864801") has completed.
# Your task (action_id="1864802") has completed.
# Your task (action_id="1864803") has completed.
# Your task (action_id="1864804") has completed.
# Your task (action_id="1864805") has completed.
# Your task (action_id="1864806") has completed.
# Your task (action_id="1864807") is queued.
# Your task (action_id="1864807") has completed.
# Your task (action_id="1864808") has completed.
# Your task (action_id="1864809") has started.
# Your task (action_id="1864809") has completed.
# Your task (action_id="1864810") has completed.
# Your task (action_id="1864811") has completed.
# Your task (action_id="1864812") has completed.
# Your task (action_id="1864813") has completed.
# Your task (action_id="1864814") has started.
# Your task (action_id="1864814") has completed.
# Your task (action_id="1864815") has completed.
# Your task (action_id="1864816") has completed.
# Your task (action_id="1864817") has completed.
# Your task (action_id="1864818") has completed.
# Your task (action_id="1864819") has started.
# Your task (action_id="1864819") has completed.
# Your task (action_id="1864820") has completed.
# Your task (action_id="1864821") has completed.
# Your task (action_id="1864822") is queued.
# Your task (action_id="1864822") has completed.
# Your task (action_id="1864823") has completed.
# Your task (action_id="1864824") has started.
# Your task (action_id="1864824") has completed.
# Your task (action_id="1864825") has completed.
# Your task (action_id="1864826") has completed.
# Your task (action_id="1864827") has completed.
# Your task (action_id="1864828") has completed.
# Your task (action_id="1864829") has started.
# Your task (action_id="1864829") has completed.
# Your task (action_id="1864830") has completed.
# Your task (action_id="1864831") has completed.
# Your task (action_id="1864832") has completed.
# Your task (action_id="1864833") has completed.
# Your task (action_id="1864834") has completed.
# Your task (action_id="1864835") has completed.
# Your task (action_id="1864836") has completed.

# %%
plt.plot(np.linspace(0,2*np.pi,100),fidelities)
plt.xlabel("$\\theta$")
plt.ylabel("infidelity")
plt.xlabel("$\\theta$")
plt.ylabel("infidelity")
plt.plot(np.linspace(0,2*np.pi,100),[np.mean(fidelities)]*len(np.linspace(0,2*np.pi,100)),'--')
plt.title("Infidelity Plot (Interpolation)")
# Out:
# Text(0.5, 1.0, 'Infidelity Plot (Interpolation)')

# %%
thetac = max(np.linspace(0,2*np.pi,100), key = lambda v : fidelities[list(np.linspace(0,2*np.pi,100)).index(v)])
print("Problem Angle: "+str(thetac))
# Out:
# Problem Angle: 2.1578616206475347

# %%
new_coefficients = []
new_fidelities = []
problem_thetas = [thetac]
for _ in range(10):
    print("------------")
    print("Iteration: "+str(_))
    print("------------")
    new_coefficients = []
    new_fidelities = []
    theta_list = list(np.linspace(0,2*np.pi,20))+problem_thetas
    theta_list.sort()
    for theta in theta_list:
        if(theta==0):
            initial = initial = {i:None for i in pulse_names}
        else:
            initial = new_coefficients[len(new_coefficients)-1]
        optimization=scheme_optimization(20,excitation(theta),initial)
        d={i:optimization['output'][i]['values'] for i in optimization['output']if('values' in optimization['output'][i])}
        new_coefficients.append(d)
            
    for theta in np.linspace(0,2*np.pi,100):
        initial=interpolate(theta,theta_list,new_coefficients)
        simulation=simulate(initial,excitation(theta))
        new_fidelities.append(simulation['output']['infidelity']['value'])
    thetac = max(np.linspace(0,2*np.pi,100), key = lambda v : new_fidelities[list(np.linspace(0,2*np.pi,100)).index(v)])
    print("Problem Angle: "+str(thetac))
    problem_thetas.append(thetac)
# Out:
# ------------
# Iteration: 0
# ------------
# Your task (action_id="1864837") has started.
# Your task (action_id="1864837") has completed.
# Your task (action_id="1864838") has started.
# Your task (action_id="1864838") has completed.
# Your task (action_id="1864839") is queued.
# Your task (action_id="1864839") has completed.
# Your task (action_id="1864840") has started.
# Your task (action_id="1864840") has completed.
# Your task (action_id="1864841") has started.
# Your task (action_id="1864841") has completed.
# Your task (action_id="1864842") has started.
# Your task (action_id="1864842") has completed.
# Your task (action_id="1864843") has started.
# Your task (action_id="1864843") has completed.
# Your task (action_id="1864844") has started.
# Your task (action_id="1864844") has completed.
# Your task (action_id="1864845") is queued.
# Your task (action_id="1864845") has completed.
# Your task (action_id="1864846") has started.
# Your task (action_id="1864846") has completed.
# Your task (action_id="1864847") has started.
# Your task (action_id="1864847") has completed.
# Your task (action_id="1864848") has started.
# Your task (action_id="1864848") has completed.
# Your task (action_id="1864849") has started.
# Your task (action_id="1864849") has completed.
# Your task (action_id="1864850") has started.
# Your task (action_id="1864850") has completed.
# Your task (action_id="1864851") is queued.
# Your task (action_id="1864851") has completed.
# Your task (action_id="1864852") has completed.
# Your task (action_id="1864853") has started.
# Your task (action_id="1864853") has completed.
# Your task (action_id="1864854") has started.
# Your task (action_id="1864854") has completed.
# Your task (action_id="1864855") has started.
# Your task (action_id="1864855") has completed.
# Your task (action_id="1864856") has started.
# Your task (action_id="1864856") has completed.
# Your task (action_id="1864857") has started.
# Your task (action_id="1864857") has completed.
# Your task (action_id="1864858") has completed.
# Your task (action_id="1864859") has started.
# Your task (action_id="1864859") has completed.
# Your task (action_id="1864860") has completed.
# Your task (action_id="1864861") has completed.
# Your task (action_id="1864862") has completed.
# Your task (action_id="1864863") has completed.
# Your task (action_id="1864864") has started.
# Your task (action_id="1864864") has completed.
# Your task (action_id="1864865") has completed.
# Your task (action_id="1864866") has completed.
# Your task (action_id="1864867") has completed.
# Your task (action_id="1864868") has completed.
# Your task (action_id="1864869") has completed.
# Your task (action_id="1864870") has completed.
# Your task (action_id="1864871") has completed.
# Your task (action_id="1864872") has completed.
# Your task (action_id="1864873") has completed.
# Your task (action_id="1864874") has started.
# Your task (action_id="1864874") has completed.
# Your task (action_id="1864875") has completed.
# Your task (action_id="1864876") has completed.
# Your task (action_id="1864877") has completed.
# Your task (action_id="1864878") has completed.
# Your task (action_id="1864879") has started.
# Your task (action_id="1864879") has completed.
# Your task (action_id="1864880") has completed.
# Your task (action_id="1864881") has completed.
# Your task (action_id="1864882") has completed.
# Your task (action_id="1864883") has completed.
# Your task (action_id="1864884") has started.
# Your task (action_id="1864884") has completed.
# Your task (action_id="1864885") has completed.
# Your task (action_id="1864886") has completed.
# Your task (action_id="1864887") has completed.
# Your task (action_id="1864888") has completed.
# Your task (action_id="1864889") has started.
# Your task (action_id="1864889") has completed.
# Your task (action_id="1864890") has completed.
# Your task (action_id="1864891") has completed.
# Your task (action_id="1864892") has completed.
# Your task (action_id="1864893") has completed.
# Your task (action_id="1864894") has started.
# Your task (action_id="1864894") has completed.
# Your task (action_id="1864895") has completed.
# Your task (action_id="1864896") has completed.
# Your task (action_id="1864897") has completed.
# Your task (action_id="1864898") has completed.
# Your task (action_id="1864899") has started.
# Your task (action_id="1864899") has completed.
# Your task (action_id="1864900") has completed.
# Your task (action_id="1864901") has completed.
# Your task (action_id="1864902") has completed.
# Your task (action_id="1864903") has completed.
# Your task (action_id="1864904") has started.
# Your task (action_id="1864904") has completed.
# Your task (action_id="1864905") has completed.
# Your task (action_id="1864906") has completed.
# Your task (action_id="1864907") has completed.
# Your task (action_id="1864908") has completed.
# Your task (action_id="1864909") has started.
# Your task (action_id="1864909") has completed.
# Your task (action_id="1864910") has completed.
# Your task (action_id="1864911") has completed.
# Your task (action_id="1864912") has completed.
# Your task (action_id="1864913") has completed.
# Your task (action_id="1864914") has started.
# Your task (action_id="1864914") has completed.
# Your task (action_id="1864915") has completed.
# Your task (action_id="1864916") has completed.
# Your task (action_id="1864917") has completed.
# Your task (action_id="1864918") has completed.
# Your task (action_id="1864919") has started.
# Your task (action_id="1864919") has completed.
# Your task (action_id="1864920") has completed.
# Your task (action_id="1864921") has completed.
# Your task (action_id="1864922") has completed.
# Your task (action_id="1864923") has completed.
# Your task (action_id="1864924") has started.
# Your task (action_id="1864924") has completed.
# Your task (action_id="1864925") has completed.
# Your task (action_id="1864926") has completed.
# Your task (action_id="1864927") has completed.
# Your task (action_id="1864928") has completed.
# Your task (action_id="1864929") has started.
# Your task (action_id="1864929") has completed.
# Your task (action_id="1864930") has completed.
# Your task (action_id="1864931") has completed.
# Your task (action_id="1864932") has completed.
# Your task (action_id="1864933") has completed.
# Your task (action_id="1864934") has started.
# Your task (action_id="1864934") has completed.
# Your task (action_id="1864935") has completed.
# Your task (action_id="1864936") has completed.
# Your task (action_id="1864937") has completed.
# Your task (action_id="1864938") has completed.
# Your task (action_id="1864939") has started.
# Your task (action_id="1864939") has completed.
# Your task (action_id="1864940") has completed.
# Your task (action_id="1864941") has completed.
# Your task (action_id="1864942") has completed.
# Your task (action_id="1864943") has completed.
# Your task (action_id="1864944") has started.
# Your task (action_id="1864944") has completed.
# Your task (action_id="1864945") has completed.
# Your task (action_id="1864946") has completed.
# Your task (action_id="1864947") has completed.
# Your task (action_id="1864948") has completed.
# Your task (action_id="1864949") has started.
# Your task (action_id="1864949") has completed.
# Your task (action_id="1864950") has completed.
# Your task (action_id="1864951") has completed.
# Your task (action_id="1864952") has completed.
# Your task (action_id="1864953") has completed.
# Your task (action_id="1864954") has started.
# Your task (action_id="1864954") has completed.
# Your task (action_id="1864955") has completed.
# Your task (action_id="1864956") has completed.
# Your task (action_id="1864957") has completed.
# Problem Angle: 1.4597299198498028
# ------------
# Iteration: 1
# ------------
# Your task (action_id="1864958") has started.
# Your task (action_id="1864958") has completed.
# Your task (action_id="1864959") has completed.
# Your task (action_id="1864960") has completed.
# Your task (action_id="1864961") is queued.
# Your task (action_id="1864961") has completed.
# Your task (action_id="1864962") has completed.
# Your task (action_id="1864963") is queued.
# Your task (action_id="1864963") has started.
# Your task (action_id="1864963") has completed.
# Your task (action_id="1864964") has completed.
# Your task (action_id="1864965") is queued.
# Your task (action_id="1864965") has started.
# Your task (action_id="1864965") has completed.
# Your task (action_id="1864966") has completed.
# Your task (action_id="1864967") is queued.
# Your task (action_id="1864967") has completed.
# Your task (action_id="1864968") has completed.
# Your task (action_id="1864969") has completed.
# Your task (action_id="1864970") has completed.
# Your task (action_id="1864971") has completed.
# Your task (action_id="1864972") has completed.
# Your task (action_id="1864973") has completed.
# Your task (action_id="1864974") has completed.
# Your task (action_id="1864975") has started.
# Your task (action_id="1864975") has completed.
# Your task (action_id="1864976") has completed.
# Your task (action_id="1864977") is queued.
# Your task (action_id="1864977") has completed.
# Your task (action_id="1864978") has completed.
# Your task (action_id="1864979") has completed.
# Your task (action_id="1864980") has completed.
# Your task (action_id="1864981") has completed.
# Your task (action_id="1864982") has completed.
# Your task (action_id="1864983") has completed.
# Your task (action_id="1864984") has completed.
# Your task (action_id="1864985") has completed.
# Your task (action_id="1864986") has started.
# Your task (action_id="1864986") has completed.
# Your task (action_id="1864987") has completed.
# Your task (action_id="1864988") has completed.
# Your task (action_id="1864989") has completed.
# Your task (action_id="1864990") has completed.
# Your task (action_id="1864991") has started.
# Your task (action_id="1864991") has completed.
# Your task (action_id="1864992") has completed.
# Your task (action_id="1864993") has completed.
# Your task (action_id="1864994") has completed.
# Your task (action_id="1864995") has completed.
# Your task (action_id="1864996") has started.
# Your task (action_id="1864996") has completed.
# Your task (action_id="1864997") has completed.
# Your task (action_id="1864998") has completed.
# Your task (action_id="1864999") has completed.
# Your task (action_id="1865000") has completed.
# Your task (action_id="1865001") has started.
# Your task (action_id="1865001") has completed.
# Your task (action_id="1865002") has completed.
# Your task (action_id="1865003") has completed.
# Your task (action_id="1865004") has completed.
# Your task (action_id="1865005") has completed.
# Your task (action_id="1865006") has started.
# Your task (action_id="1865006") has completed.
# Your task (action_id="1865007") has completed.
# Your task (action_id="1865008") has completed.
# Your task (action_id="1865009") has completed.
# Your task (action_id="1865010") has completed.
# Your task (action_id="1865011") has started.
# Your task (action_id="1865011") has completed.
# Your task (action_id="1865012") has completed.
# Your task (action_id="1865013") has completed.
# Your task (action_id="1865014") has completed.
# Your task (action_id="1865015") has completed.
# Your task (action_id="1865016") has started.
# Your task (action_id="1865016") has completed.
# Your task (action_id="1865017") has completed.
# Your task (action_id="1865018") has completed.
# Your task (action_id="1865019") has completed.
# Your task (action_id="1865020") has completed.
# Your task (action_id="1865021") has started.
# Your task (action_id="1865021") has completed.
# Your task (action_id="1865022") has completed.
# Your task (action_id="1865023") has completed.
# Your task (action_id="1865024") has completed.
# Your task (action_id="1865025") has completed.
# Your task (action_id="1865026") has started.
# Your task (action_id="1865026") has completed.
# Your task (action_id="1865027") has completed.
# Your task (action_id="1865028") has completed.
# Your task (action_id="1865029") has completed.
# Your task (action_id="1865030") has completed.
# Your task (action_id="1865031") has started.
# Your task (action_id="1865031") has completed.
# Your task (action_id="1865032") has completed.
# Your task (action_id="1865033") has completed.
# Your task (action_id="1865034") has completed.
# Your task (action_id="1865035") has completed.
# Your task (action_id="1865036") has started.
# Your task (action_id="1865036") has completed.
# Your task (action_id="1865037") has completed.
# Your task (action_id="1865038") has completed.
# Your task (action_id="1865039") has completed.
# Your task (action_id="1865040") has completed.
# Your task (action_id="1865041") has completed.
# Your task (action_id="1865042") has completed.
# Your task (action_id="1865043") has completed.
# Your task (action_id="1865044") has completed.
# Your task (action_id="1865045") has completed.
# Your task (action_id="1865046") has completed.
# Your task (action_id="1865047") has completed.
# Your task (action_id="1865048") has completed.
# Your task (action_id="1865049") has completed.
# Your task (action_id="1865050") has completed.
# Your task (action_id="1865051") has started.
# Your task (action_id="1865051") has completed.
# Your task (action_id="1865052") has completed.
# Your task (action_id="1865053") has completed.
# Your task (action_id="1865054") has completed.
# Your task (action_id="1865055") has completed.
# Your task (action_id="1865056") has started.
# Your task (action_id="1865056") has completed.
# Your task (action_id="1865057") has completed.
# Your task (action_id="1865058") has completed.
# Your task (action_id="1865059") has completed.
# Your task (action_id="1865060") has completed.
# Your task (action_id="1865061") has started.
# Your task (action_id="1865061") has completed.
# Your task (action_id="1865062") has completed.
# Your task (action_id="1865063") has completed.
# Your task (action_id="1865064") has completed.
# Your task (action_id="1865065") has completed.
# Your task (action_id="1865066") has started.
# Your task (action_id="1865066") has completed.
# Your task (action_id="1865067") has completed.
# Your task (action_id="1865068") has completed.
# Your task (action_id="1865069") has completed.
# Your task (action_id="1865070") has completed.
# Your task (action_id="1865071") has started.
# Your task (action_id="1865071") has completed.
# Your task (action_id="1865072") has completed.
# Your task (action_id="1865073") has completed.
# Your task (action_id="1865074") has completed.
# Your task (action_id="1865075") has completed.
# Your task (action_id="1865076") has started.
# Your task (action_id="1865076") has completed.
# Your task (action_id="1865077") has completed.
# Your task (action_id="1865078") has completed.
# Your task (action_id="1865079") has completed.
# Problem Angle: 5.775453161144872
# ------------
# Iteration: 2
# ------------
# Your task (action_id="1865080") has completed.
# Your task (action_id="1865081") has completed.
# Your task (action_id="1865082") has completed.
# Your task (action_id="1865083") has started.
# Your task (action_id="1865083") has completed.
# Your task (action_id="1865084") has completed.
# Your task (action_id="1865085") is queued.
# Your task (action_id="1865085") has started.
# Your task (action_id="1865085") has completed.
# Your task (action_id="1865086") has started.
# Your task (action_id="1865086") has completed.
# Your task (action_id="1865087") has started.
# Your task (action_id="1865087") has completed.
# Your task (action_id="1865088") has completed.
# Your task (action_id="1865089") is queued.
# Your task (action_id="1865089") has completed.
# Your task (action_id="1865090") has completed.
# Your task (action_id="1865091") has completed.
# Your task (action_id="1865092") has completed.
# Your task (action_id="1865093") has started.
# Your task (action_id="1865093") has completed.
# Your task (action_id="1865094") has completed.
# Your task (action_id="1865095") is queued.
# Your task (action_id="1865095") has completed.
# Your task (action_id="1865096") has completed.
# Your task (action_id="1865097") has started.
# Your task (action_id="1865097") has completed.
# Your task (action_id="1865098") has completed.
# Your task (action_id="1865099") is queued.
# Your task (action_id="1865099") has completed.
# Your task (action_id="1865100") has completed.
# Your task (action_id="1865101") has started.
# Your task (action_id="1865101") has completed.
# Your task (action_id="1865102") has completed.
# Your task (action_id="1865103") is queued.
# Your task (action_id="1865103") has completed.
# Your task (action_id="1865104") has completed.
# Your task (action_id="1865105") has started.
# Your task (action_id="1865105") has completed.
# Your task (action_id="1865106") has completed.
# Your task (action_id="1865107") has completed.
# Your task (action_id="1865108") is queued.
# Your task (action_id="1865108") has completed.
# Your task (action_id="1865109") has completed.
# Your task (action_id="1865110") has started.
# Your task (action_id="1865110") has completed.
# Your task (action_id="1865111") has completed.
# Your task (action_id="1865112") has completed.
# Your task (action_id="1865113") has completed.
# Your task (action_id="1865114") has completed.
# Your task (action_id="1865115") has started.
# Your task (action_id="1865115") has completed.
# Your task (action_id="1865116") has completed.
# Your task (action_id="1865117") has completed.
# Your task (action_id="1865118") is queued.
# Your task (action_id="1865118") has completed.
# Your task (action_id="1865119") has completed.
# Your task (action_id="1865120") has started.
# Your task (action_id="1865120") has completed.
# Your task (action_id="1865121") has completed.
# Your task (action_id="1865122") has completed.
# Your task (action_id="1865123") has completed.
# Your task (action_id="1865124") has completed.
# Your task (action_id="1865125") has started.
# Your task (action_id="1865125") has completed.
# Your task (action_id="1865126") has completed.
# Your task (action_id="1865127") has completed.
# Your task (action_id="1865128") is queued.
# Your task (action_id="1865128") has completed.
# Your task (action_id="1865129") has completed.
# Your task (action_id="1865130") has started.
# Your task (action_id="1865130") has completed.
# Your task (action_id="1865131") has completed.
# Your task (action_id="1865132") has completed.
# Your task (action_id="1865133") is queued.
# Your task (action_id="1865133") has completed.
# Your task (action_id="1865134") has completed.
# Your task (action_id="1865135") has started.
# Your task (action_id="1865135") has completed.
# Your task (action_id="1865136") has completed.
# Your task (action_id="1865137") has completed.
# Your task (action_id="1865138") is queued.
# Your task (action_id="1865138") has completed.
# Your task (action_id="1865139") has completed.
# Your task (action_id="1865140") has started.
# Your task (action_id="1865140") has completed.
# Your task (action_id="1865141") has completed.
# Your task (action_id="1865142") has completed.
# Your task (action_id="1865143") is queued.
# Your task (action_id="1865143") has completed.
# Your task (action_id="1865144") has completed.
# Your task (action_id="1865145") has started.
# Your task (action_id="1865145") has completed.
# Your task (action_id="1865146") has completed.
# Your task (action_id="1865147") has completed.
# Your task (action_id="1865148") has completed.
# Your task (action_id="1865149") has completed.
# Your task (action_id="1865150") has started.
# Your task (action_id="1865150") has completed.
# Your task (action_id="1865151") has completed.
# Your task (action_id="1865152") has completed.
# Your task (action_id="1865153") is queued.
# Your task (action_id="1865153") has completed.
# Your task (action_id="1865154") has completed.
# Your task (action_id="1865155") has started.
# Your task (action_id="1865155") has completed.
# Your task (action_id="1865156") has completed.
# Your task (action_id="1865157") has completed.
# Your task (action_id="1865158") has completed.
# Your task (action_id="1865159") has completed.
# Your task (action_id="1865160") has completed.
# Your task (action_id="1865161") has completed.
# Your task (action_id="1865162") has completed.
# Your task (action_id="1865163") is queued.
# Your task (action_id="1865163") has completed.
# Your task (action_id="1865164") has completed.
# Your task (action_id="1865165") has started.
# Your task (action_id="1865165") has completed.
# Your task (action_id="1865166") has completed.
# Your task (action_id="1865167") has completed.
# Your task (action_id="1865168") is queued.
# Your task (action_id="1865168") has completed.
# Your task (action_id="1865169") has completed.
# Your task (action_id="1865170") has started.
# Your task (action_id="1865170") has completed.
# Your task (action_id="1865171") has completed.
# Your task (action_id="1865172") has completed.
# Your task (action_id="1865173") is queued.
# Your task (action_id="1865173") has completed.
# Your task (action_id="1865174") has completed.
# Your task (action_id="1865175") has started.
# Your task (action_id="1865175") has completed.
# Your task (action_id="1865176") has completed.
# Your task (action_id="1865177") has completed.
# Your task (action_id="1865178") is queued.
# Your task (action_id="1865178") has completed.
# Your task (action_id="1865179") has completed.
# Your task (action_id="1865180") has started.
# Your task (action_id="1865180") has completed.
# Your task (action_id="1865181") has completed.
# Your task (action_id="1865182") has completed.
# Your task (action_id="1865183") is queued.
# Your task (action_id="1865183") has completed.
# Your task (action_id="1865184") has completed.
# Your task (action_id="1865185") has started.
# Your task (action_id="1865185") has completed.
# Your task (action_id="1865186") has completed.
# Your task (action_id="1865187") has completed.
# Your task (action_id="1865188") is queued.
# Your task (action_id="1865188") has completed.
# Your task (action_id="1865189") has completed.
# Your task (action_id="1865190") has started.
# Your task (action_id="1865190") has completed.
# Your task (action_id="1865191") has completed.
# Your task (action_id="1865192") has completed.
# Your task (action_id="1865193") is queued.
# Your task (action_id="1865193") has completed.
# Your task (action_id="1865194") has completed.
# Your task (action_id="1865195") has completed.
# Your task (action_id="1865196") has completed.
# Your task (action_id="1865197") has completed.
# Your task (action_id="1865198") is queued.
# Your task (action_id="1865198") has completed.
# Your task (action_id="1865199") has completed.
# Your task (action_id="1865200") has started.
# Your task (action_id="1865200") has completed.
# Your task (action_id="1865201") has completed.
# Your task (action_id="1865202") has completed.
# Problem Angle: 0.1903995547630178
# ------------
# Iteration: 3
# ------------
# Your task (action_id="1865203") is queued.
# Your task (action_id="1865203") has completed.
# Your task (action_id="1865204") has completed.
# Your task (action_id="1865205") has completed.
# Your task (action_id="1865206") has completed.
# Your task (action_id="1865207") has completed.
# Your task (action_id="1865208") has completed.
# Your task (action_id="1865209") has completed.
# Your task (action_id="1865210") has completed.
# Your task (action_id="1865211") has started.
# Your task (action_id="1865211") has completed.
# Your task (action_id="1865212") has completed.
# Your task (action_id="1865213") is queued.
# Your task (action_id="1865213") has completed.
# Your task (action_id="1865214") has completed.
# Your task (action_id="1865215") has completed.
# Your task (action_id="1865216") has completed.
# Your task (action_id="1865217") has completed.
# Your task (action_id="1865218") has completed.
# Your task (action_id="1865219") has completed.
# Your task (action_id="1865220") has completed.
# Your task (action_id="1865221") has started.
# Your task (action_id="1865221") has completed.
# Your task (action_id="1865222") has completed.
# Your task (action_id="1865223") has started.
# Your task (action_id="1865223") has completed.
# Your task (action_id="1865224") has completed.
# Your task (action_id="1865225") has completed.
# Your task (action_id="1865226") has completed.
# Your task (action_id="1865227") has completed.
# Your task (action_id="1865228") has completed.
# Your task (action_id="1865229") has started.
# Your task (action_id="1865229") has completed.
# Your task (action_id="1865230") has completed.
# Your task (action_id="1865231") has completed.
# Your task (action_id="1865232") has completed.
# Your task (action_id="1865233") has completed.
# Your task (action_id="1865234") has started.
# Your task (action_id="1865234") has completed.
# Your task (action_id="1865235") has completed.
# Your task (action_id="1865236") has completed.
# Your task (action_id="1865237") is queued.
# Your task (action_id="1865237") has completed.
# Your task (action_id="1865238") has completed.
# Your task (action_id="1865239") has started.
# Your task (action_id="1865239") has completed.
# Your task (action_id="1865240") has completed.
# Your task (action_id="1865241") has completed.
# Your task (action_id="1865242") is queued.
# Your task (action_id="1865242") has completed.
# Your task (action_id="1865243") has completed.
# Your task (action_id="1865244") has started.
# Your task (action_id="1865244") has completed.
# Your task (action_id="1865245") has completed.
# Your task (action_id="1865246") has completed.
# Your task (action_id="1865247") is queued.
# Your task (action_id="1865247") has completed.
# Your task (action_id="1865248") has completed.
# Your task (action_id="1865249") has completed.
# Your task (action_id="1865250") has completed.
# Your task (action_id="1865251") has completed.
# Your task (action_id="1865252") is queued.
# Your task (action_id="1865252") has completed.
# Your task (action_id="1865253") has completed.
# Your task (action_id="1865254") has started.
# Your task (action_id="1865254") has completed.
# Your task (action_id="1865255") has completed.
# Your task (action_id="1865256") has completed.
# Your task (action_id="1865257") is queued.
# Your task (action_id="1865257") has completed.
# Your task (action_id="1865258") has completed.
# Your task (action_id="1865259") has started.
# Your task (action_id="1865259") has completed.
# Your task (action_id="1865260") has completed.
# Your task (action_id="1865261") has completed.
# Your task (action_id="1865262") is queued.
# Your task (action_id="1865262") has completed.
# Your task (action_id="1865263") has completed.
# Your task (action_id="1865264") has started.
# Your task (action_id="1865264") has completed.
# Your task (action_id="1865265") has completed.
# Your task (action_id="1865266") has completed.
# Your task (action_id="1865267") is queued.
# Your task (action_id="1865267") has completed.
# Your task (action_id="1865268") has completed.
# Your task (action_id="1865269") has completed.
# Your task (action_id="1865270") has completed.
# Your task (action_id="1865271") has completed.
# Your task (action_id="1865272") is queued.
# Your task (action_id="1865272") has completed.
# Your task (action_id="1865273") has completed.
# Your task (action_id="1865274") has started.
# Your task (action_id="1865274") has completed.
# Your task (action_id="1865275") has completed.
# Your task (action_id="1865276") has completed.
# Your task (action_id="1865277") is queued.
# Your task (action_id="1865277") has completed.
# Your task (action_id="1865278") has completed.
# Your task (action_id="1865279") has started.
# Your task (action_id="1865279") has completed.
# Your task (action_id="1865280") has completed.
# Your task (action_id="1865281") has completed.
# Your task (action_id="1865282") has completed.
# Your task (action_id="1865283") has completed.
# Your task (action_id="1865284") has started.
# Your task (action_id="1865284") has completed.
# Your task (action_id="1865285") has completed.
# Your task (action_id="1865286") has completed.
# Your task (action_id="1865287") is queued.
# Your task (action_id="1865287") has completed.
# Your task (action_id="1865288") has completed.
# Your task (action_id="1865289") has started.
# Your task (action_id="1865289") has completed.
# Your task (action_id="1865290") has completed.
# Your task (action_id="1865291") has completed.
# Your task (action_id="1865292") has completed.
# Your task (action_id="1865293") has completed.
# Your task (action_id="1865294") has completed.
# Your task (action_id="1865295") has completed.
# Your task (action_id="1865296") has completed.
# Your task (action_id="1865297") has completed.
# Your task (action_id="1865298") has completed.
# Your task (action_id="1865299") has started.
# Your task (action_id="1865299") has completed.
# Your task (action_id="1865300") has completed.
# Your task (action_id="1865301") has completed.
# Your task (action_id="1865302") is queued.
# Your task (action_id="1865302") has completed.
# Your task (action_id="1865303") has completed.
# Your task (action_id="1865304") has started.
# Your task (action_id="1865304") has completed.
# Your task (action_id="1865305") has completed.
# Your task (action_id="1865306") has completed.
# Your task (action_id="1865307") is queued.
# Your task (action_id="1865307") has completed.
# Your task (action_id="1865308") has completed.
# Your task (action_id="1865309") has started.
# Your task (action_id="1865309") has completed.
# Your task (action_id="1865310") has completed.
# Your task (action_id="1865311") has completed.
# Your task (action_id="1865312") is queued.
# Your task (action_id="1865312") has completed.
# Your task (action_id="1865313") has completed.
# Your task (action_id="1865314") has completed.
# Your task (action_id="1865315") has completed.
# Your task (action_id="1865316") has completed.
# Your task (action_id="1865317") has completed.
# Your task (action_id="1865318") has completed.
# Your task (action_id="1865319") has started.
# Your task (action_id="1865319") has completed.
# Your task (action_id="1865320") has completed.
# Your task (action_id="1865321") has completed.
# Your task (action_id="1865322") has completed.
# Your task (action_id="1865323") has completed.
# Your task (action_id="1865324") has started.
# Your task (action_id="1865324") has completed.
# Your task (action_id="1865325") has completed.
# Your task (action_id="1865326") has completed.
# Problem Angle: 1.8405290293758385
# ------------
# Iteration: 4
# ------------
# Your task (action_id="1865327") is queued.
# Your task (action_id="1865327") has completed.
# Your task (action_id="1865328") has completed.
# Your task (action_id="1865329") has started.
# Your task (action_id="1865329") has completed.
# Your task (action_id="1865330") has started.
# Your task (action_id="1865330") has completed.
# Your task (action_id="1865331") has started.
# Your task (action_id="1865331") has completed.
# Your task (action_id="1865332") has started.
# Your task (action_id="1865332") has completed.
# Your task (action_id="1865333") has started.
# Your task (action_id="1865333") has completed.
# Your task (action_id="1865334") has completed.
# Your task (action_id="1865335") has completed.
# Your task (action_id="1865336") has completed.
# Your task (action_id="1865337") has started.
# Your task (action_id="1865337") has completed.
# Your task (action_id="1865338") has completed.
# Your task (action_id="1865339") is queued.
# Your task (action_id="1865339") has completed.
# Your task (action_id="1865340") has completed.
# Your task (action_id="1865341") has completed.
# Your task (action_id="1865342") has completed.
# Your task (action_id="1865343") has started.
# Your task (action_id="1865343") has completed.
# Your task (action_id="1865344") has completed.
# Your task (action_id="1865345") has started.
# Your task (action_id="1865345") has completed.
# Your task (action_id="1865346") has started.
# Your task (action_id="1865346") has completed.
# Your task (action_id="1865347") has started.
# Your task (action_id="1865347") has completed.
# Your task (action_id="1865348") has completed.
# Your task (action_id="1865349") has completed.
# Your task (action_id="1865350") has completed.
# Your task (action_id="1865351") has started.
# Your task (action_id="1865351") has completed.
# Your task (action_id="1865352") has completed.
# Your task (action_id="1865353") has completed.
# Your task (action_id="1865354") has completed.
# Your task (action_id="1865355") has completed.
# Your task (action_id="1865356") has completed.
# Your task (action_id="1865357") has completed.
# Your task (action_id="1865358") has started.
# Your task (action_id="1865358") has completed.
# Your task (action_id="1865359") has completed.
# Your task (action_id="1865360") has completed.
# Your task (action_id="1865361") has completed.
# Your task (action_id="1865362") has completed.
# Your task (action_id="1865363") has started.
# Your task (action_id="1865363") has completed.
# Your task (action_id="1865364") has completed.
# Your task (action_id="1865365") has completed.
# Your task (action_id="1865366") has completed.
# Your task (action_id="1865367") has completed.
# Your task (action_id="1865368") has started.
# Your task (action_id="1865368") has completed.
# Your task (action_id="1865369") has completed.
# Your task (action_id="1865370") has completed.
# Your task (action_id="1865371") has completed.
# Your task (action_id="1865372") has completed.
# Your task (action_id="1865373") has started.
# Your task (action_id="1865373") has completed.
# Your task (action_id="1865374") has completed.
# Your task (action_id="1865375") has completed.
# Your task (action_id="1865376") is queued.
# Your task (action_id="1865376") has completed.
# Your task (action_id="1865377") has completed.
# Your task (action_id="1865378") has started.
# Your task (action_id="1865378") has completed.
# Your task (action_id="1865379") has completed.
# Your task (action_id="1865380") has completed.
# Your task (action_id="1865381") has completed.
# Your task (action_id="1865382") has completed.
# Your task (action_id="1865383") has started.
# Your task (action_id="1865383") has completed.
# Your task (action_id="1865384") has completed.
# Your task (action_id="1865385") has completed.
# Your task (action_id="1865386") has completed.
# Your task (action_id="1865387") has completed.
# Your task (action_id="1865388") has started.
# Your task (action_id="1865388") has completed.
# Your task (action_id="1865389") has completed.
# Your task (action_id="1865390") has completed.
# Your task (action_id="1865391") has completed.
# Your task (action_id="1865392") has completed.
# Your task (action_id="1865393") has started.
# Your task (action_id="1865393") has completed.
# Your task (action_id="1865394") has completed.
# Your task (action_id="1865395") has completed.
# Your task (action_id="1865396") has completed.
# Your task (action_id="1865397") has completed.
# Your task (action_id="1865398") has started.
# Your task (action_id="1865398") has completed.
# Your task (action_id="1865399") has completed.
# Your task (action_id="1865400") has completed.
# Your task (action_id="1865401") has completed.
# Your task (action_id="1865402") has completed.
# Your task (action_id="1865403") has started.
# Your task (action_id="1865403") has completed.
# Your task (action_id="1865404") has completed.
# Your task (action_id="1865405") has completed.
# Your task (action_id="1865406") has completed.
# Your task (action_id="1865407") has completed.
# Your task (action_id="1865408") has completed.
# Your task (action_id="1865409") has completed.
# Your task (action_id="1865410") has completed.
# Your task (action_id="1865411") has completed.
# Your task (action_id="1865412") has completed.
# Your task (action_id="1865413") has started.
# Your task (action_id="1865413") has completed.
# Your task (action_id="1865414") has completed.
# Your task (action_id="1865415") has completed.
# Your task (action_id="1865416") has completed.
# Your task (action_id="1865417") has completed.
# Your task (action_id="1865418") has started.
# Your task (action_id="1865418") has completed.
# Your task (action_id="1865419") has completed.
# Your task (action_id="1865420") has completed.
# Your task (action_id="1865421") has completed.
# Your task (action_id="1865422") has completed.
# Your task (action_id="1865423") has started.
# Your task (action_id="1865423") has completed.
# Your task (action_id="1865424") has completed.
# Your task (action_id="1865425") has completed.
# Your task (action_id="1865426") has completed.
# Your task (action_id="1865427") has completed.
# Your task (action_id="1865428") has started.
# Your task (action_id="1865428") has completed.
# Your task (action_id="1865429") has completed.
# Your task (action_id="1865430") has completed.
# Your task (action_id="1865431") has completed.
# Your task (action_id="1865432") has completed.
# Your task (action_id="1865433") has started.
# Your task (action_id="1865433") has completed.
# Your task (action_id="1865434") has completed.
# Your task (action_id="1865435") has completed.
# Your task (action_id="1865436") has completed.
# Your task (action_id="1865437") has completed.
# Your task (action_id="1865438") has started.
# Your task (action_id="1865438") has completed.
# Your task (action_id="1865439") has completed.
# Your task (action_id="1865440") has completed.
# Your task (action_id="1865441") has completed.
# Your task (action_id="1865442") has completed.
# Your task (action_id="1865443") has started.
# Your task (action_id="1865443") has completed.
# Your task (action_id="1865444") has completed.
# Your task (action_id="1865445") has completed.
# Your task (action_id="1865446") has completed.
# Your task (action_id="1865447") has completed.
# Your task (action_id="1865448") has completed.
# Your task (action_id="1865449") has completed.
# Your task (action_id="1865450") has completed.
# Your task (action_id="1865451") has completed.
# Problem Angle: 3.8079910952603555
# ------------
# Iteration: 5
# ------------
# Your task (action_id="1865452") has completed.
# Your task (action_id="1865453") has completed.
# Your task (action_id="1865454") has completed.
# Your task (action_id="1865455") has started.
# Your task (action_id="1865455") has completed.
# Your task (action_id="1865456") has completed.
# Your task (action_id="1865457") is queued.
# Your task (action_id="1865457") has completed.
# Your task (action_id="1865458") has completed.
# Your task (action_id="1865459") has started.
# Your task (action_id="1865459") has completed.
# Your task (action_id="1865460") has completed.
# Your task (action_id="1865461") has completed.
# Your task (action_id="1865462") has completed.
# Your task (action_id="1865463") has completed.
# Your task (action_id="1865464") has completed.
# Your task (action_id="1865465") has started.
# Your task (action_id="1865465") has completed.
# Your task (action_id="1865466") has completed.
# Your task (action_id="1865467") is queued.
# Your task (action_id="1865467") has completed.
# Your task (action_id="1865468") has started.
# Your task (action_id="1865468") has completed.
# Your task (action_id="1865469") has completed.
# Your task (action_id="1865470") has completed.
# Your task (action_id="1865471") is queued.
# Your task (action_id="1865471") has completed.
# Your task (action_id="1865472") has completed.
# Your task (action_id="1865473") has started.
# Your task (action_id="1865473") has completed.
# Your task (action_id="1865474") has completed.
# Your task (action_id="1865475") has completed.
# Your task (action_id="1865476") has completed.
# Your task (action_id="1865477") is queued.
# Your task (action_id="1865477") has completed.
# Your task (action_id="1865478") has completed.
# Your task (action_id="1865479") has completed.
# Your task (action_id="1865480") has completed.
# Your task (action_id="1865481") has completed.
# Your task (action_id="1865482") has completed.
# Your task (action_id="1865483") has completed.
# Your task (action_id="1865484") has started.
# Your task (action_id="1865484") has completed.
# Your task (action_id="1865485") has completed.
# Your task (action_id="1865486") has completed.
# Your task (action_id="1865487") has completed.
# Your task (action_id="1865488") has completed.
# Your task (action_id="1865489") has started.
# Your task (action_id="1865489") has completed.
# Your task (action_id="1865490") has completed.
# Your task (action_id="1865491") has completed.
# Your task (action_id="1865492") has completed.
# Your task (action_id="1865493") has completed.
# Your task (action_id="1865494") has started.
# Your task (action_id="1865494") has completed.
# Your task (action_id="1865495") has completed.
# Your task (action_id="1865496") has completed.
# Your task (action_id="1865497") has completed.
# Your task (action_id="1865498") has completed.
# Your task (action_id="1865499") has started.
# Your task (action_id="1865499") has completed.
# Your task (action_id="1865500") has completed.
# Your task (action_id="1865501") has completed.
# Your task (action_id="1865502") has completed.
# Your task (action_id="1865503") has completed.
# Your task (action_id="1865504") has started.
# Your task (action_id="1865504") has completed.
# Your task (action_id="1865505") has completed.
# Your task (action_id="1865506") has completed.
# Your task (action_id="1865507") is queued.
# Your task (action_id="1865507") has completed.
# Your task (action_id="1865508") has completed.
# Your task (action_id="1865509") has started.
# Your task (action_id="1865509") has completed.
# Your task (action_id="1865510") has completed.
# Your task (action_id="1865511") has completed.
# Your task (action_id="1865512") has completed.
# Your task (action_id="1865513") has completed.
# Your task (action_id="1865514") has started.
# Your task (action_id="1865514") has completed.
# Your task (action_id="1865515") has completed.
# Your task (action_id="1865516") has completed.
# Your task (action_id="1865517") has completed.
# Your task (action_id="1865518") has completed.
# Your task (action_id="1865519") has started.
# Your task (action_id="1865519") has completed.
# Your task (action_id="1865520") has completed.
# Your task (action_id="1865521") has completed.
# Your task (action_id="1865522") has completed.
# Your task (action_id="1865523") has completed.
# Your task (action_id="1865524") has started.
# Your task (action_id="1865524") has completed.
# Your task (action_id="1865525") has completed.
# Your task (action_id="1865526") has completed.
# Your task (action_id="1865527") has completed.
# Your task (action_id="1865528") has completed.
# Your task (action_id="1865529") has started.
# Your task (action_id="1865529") has completed.
# Your task (action_id="1865530") has completed.
# Your task (action_id="1865531") has completed.
# Your task (action_id="1865532") has completed.
# Your task (action_id="1865533") has completed.
# Your task (action_id="1865534") has completed.
# Your task (action_id="1865535") has completed.
# Your task (action_id="1865536") has completed.
# Your task (action_id="1865537") has completed.
# Your task (action_id="1865538") has completed.
# Your task (action_id="1865539") has completed.
# Your task (action_id="1865540") has completed.
# Your task (action_id="1865541") has completed.
# Your task (action_id="1865542") is queued.
# Your task (action_id="1865542") has completed.
# Your task (action_id="1865543") has completed.
# Your task (action_id="1865544") has completed.
# Your task (action_id="1865545") has completed.
# Your task (action_id="1865546") has completed.
# Your task (action_id="1865547") has completed.
# Your task (action_id="1865548") has completed.
# Your task (action_id="1865549") has started.
# Your task (action_id="1865549") has completed.
# Your task (action_id="1865550") has completed.
# Your task (action_id="1865551") has completed.
# Your task (action_id="1865552") has completed.
# Your task (action_id="1865553") has completed.
# Your task (action_id="1865554") has started.
# Your task (action_id="1865554") has completed.
# Your task (action_id="1865555") has completed.
# Your task (action_id="1865556") has completed.
# Your task (action_id="1865557") has completed.
# Your task (action_id="1865558") has completed.
# Your task (action_id="1865559") has started.
# Your task (action_id="1865559") has completed.
# Your task (action_id="1865560") has completed.
# Your task (action_id="1865561") has completed.
# Your task (action_id="1865562") has completed.
# Your task (action_id="1865563") has completed.
# Your task (action_id="1865564") has started.
# Your task (action_id="1865564") has completed.
# Your task (action_id="1865565") has completed.
# Your task (action_id="1865566") has completed.
# Your task (action_id="1865567") has completed.
# Your task (action_id="1865568") has completed.
# Your task (action_id="1865569") has completed.
# Your task (action_id="1865570") has completed.
# Your task (action_id="1865571") has completed.
# Your task (action_id="1865572") has completed.
# Your task (action_id="1865573") has completed.
# Your task (action_id="1865574") has started.
# Your task (action_id="1865574") has completed.
# Your task (action_id="1865575") has completed.
# Your task (action_id="1865576") has completed.
# Your task (action_id="1865577") has completed.
# Problem Angle: 4.1253236865320515
# ------------
# Iteration: 6
# ------------
# Your task (action_id="1865578") has started.
# Your task (action_id="1865578") has completed.
# Your task (action_id="1865579") has completed.
# Your task (action_id="1865580") has completed.
# Your task (action_id="1865581") is queued.
# Your task (action_id="1865581") has started.
# Your task (action_id="1865581") has completed.
# Your task (action_id="1865582") has completed.
# Your task (action_id="1865583") is queued.
# Your task (action_id="1865583") has completed.
# Your task (action_id="1865584") has completed.
# Your task (action_id="1865585") has completed.
# Your task (action_id="1865586") has completed.
# Your task (action_id="1865587") has started.
# Your task (action_id="1865587") has completed.
# Your task (action_id="1865588") has completed.
# Your task (action_id="1865589") is queued.
# Your task (action_id="1865589") has completed.
# Your task (action_id="1865590") has completed.
# Your task (action_id="1865591") is queued.
# Your task (action_id="1865591") has started.
# Your task (action_id="1865591") has completed.
# Your task (action_id="1865592") has completed.
# Your task (action_id="1865593") is queued.
# Your task (action_id="1865593") has completed.
# Your task (action_id="1865594") has completed.
# Your task (action_id="1865595") has completed.
# Your task (action_id="1865596") has completed.
# Your task (action_id="1865597") has started.
# Your task (action_id="1865597") has completed.
# Your task (action_id="1865598") has completed.
# Your task (action_id="1865599") has started.
# Your task (action_id="1865599") has completed.
# Your task (action_id="1865600") has completed.
# Your task (action_id="1865601") has completed.
# Your task (action_id="1865602") has completed.
# Your task (action_id="1865603") has started.
# Your task (action_id="1865603") has completed.
# Your task (action_id="1865604") has completed.
# Your task (action_id="1865605") is queued.
# Your task (action_id="1865605") has completed.
# Your task (action_id="1865606") has completed.
# Your task (action_id="1865607") has started.
# Your task (action_id="1865607") has completed.
# Your task (action_id="1865608") has completed.
# Your task (action_id="1865609") has completed.
# Your task (action_id="1865610") is queued.
# Your task (action_id="1865610") has completed.
# Your task (action_id="1865611") has completed.
# Your task (action_id="1865612") has started.
# Your task (action_id="1865612") has completed.
# Your task (action_id="1865613") has completed.
# Your task (action_id="1865614") has completed.
# Your task (action_id="1865615") is queued.
# Your task (action_id="1865615") has completed.
# Your task (action_id="1865616") has completed.
# Your task (action_id="1865617") has started.
# Your task (action_id="1865617") has completed.
# Your task (action_id="1865618") has completed.
# Your task (action_id="1865619") has completed.
# Your task (action_id="1865620") is queued.
# Your task (action_id="1865620") has completed.
# Your task (action_id="1865621") has completed.
# Your task (action_id="1865622") has started.
# Your task (action_id="1865622") has completed.
# Your task (action_id="1865623") has completed.
# Your task (action_id="1865624") has completed.
# Your task (action_id="1865625") is queued.
# Your task (action_id="1865625") has completed.
# Your task (action_id="1865626") has completed.
# Your task (action_id="1865627") has started.
# Your task (action_id="1865627") has completed.
# Your task (action_id="1865628") has completed.
# Your task (action_id="1865629") has completed.
# Your task (action_id="1865630") is queued.
# Your task (action_id="1865630") has completed.
# Your task (action_id="1865631") has completed.
# Your task (action_id="1865632") has completed.
# Your task (action_id="1865633") has completed.
# Your task (action_id="1865634") has completed.
# Your task (action_id="1865635") has completed.
# ...
# Your task (action_id="1865806") has completed.
# Your task (action_id="1865807") has completed.
# Your task (action_id="1865808") has completed.
# Your task (action_id="1865809") has completed.
# Your task (action_id="1865810") has started.
# Your task (action_id="1865810") has completed.
# Your task (action_id="1865811") has completed.
# Your task (action_id="1865812") has completed.
# Your task (action_id="1865813") has completed.
# Your task (action_id="1865814") has completed.
# Your task (action_id="1865815") has started.
# Your task (action_id="1865815") has completed.
# Your task (action_id="1865816") has completed.
# Your task (action_id="1865817") has completed.
# Your task (action_id="1865818") is queued.
# Your task (action_id="1865818") has completed.
# Your task (action_id="1865819") has completed.
# Your task (action_id="1865820") has completed.
# Your task (action_id="1865821") has completed.
# Your task (action_id="1865822") has completed.
# Your task (action_id="1865823") is queued.
# Your task (action_id="1865823") has completed.
# Your task (action_id="1865824") has completed.
# Your task (action_id="1865825") has started.
# Your task (action_id="1865825") has completed.
# Your task (action_id="1865826") has completed.
# Your task (action_id="1865827") has completed.
# Your task (action_id="1865828") has completed.
# Your task (action_id="1865829") has completed.
# Your task (action_id="1865830") has started.
# Your task (action_id="1865830") has completed.
# Your task (action_id="1865831") has completed.
# Your task (action_id="1865832") has completed.
# Problem Angle: 1.1423973285781066
# ------------
# Iteration: 8
# ------------
# Your task (action_id="1865833") has completed.
# Your task (action_id="1865834") has completed.
# Your task (action_id="1865835") has started.
# Your task (action_id="1865835") has completed.
# Your task (action_id="1865836") has completed.
# Your task (action_id="1865837") has started.
# Your task (action_id="1865837") has completed.
# Your task (action_id="1865838") has completed.
# Your task (action_id="1865839") has completed.
# Your task (action_id="1865840") has completed.
# Your task (action_id="1865841") has completed.
# Your task (action_id="1865842") has completed.
# Your task (action_id="1865843") has completed.
# Your task (action_id="1865844") has completed.
# Your task (action_id="1865845") has completed.
# Your task (action_id="1865846") has completed.
# Your task (action_id="1865847") has completed.
# Your task (action_id="1865848") has completed.
# Your task (action_id="1865849") has completed.
# Your task (action_id="1865850") has completed.
# Your task (action_id="1865851") has completed.
# Your task (action_id="1865852") has completed.
# Your task (action_id="1865853") has started.
# Your task (action_id="1865853") has completed.
# Your task (action_id="1865854") has completed.
# Your task (action_id="1865855") has completed.
# Your task (action_id="1865856") has completed.
# Your task (action_id="1865857") has completed.
# Your task (action_id="1865858") has completed.
# Your task (action_id="1865859") has completed.
# Your task (action_id="1865860") has completed.
# Your task (action_id="1865861") has completed.
# Your task (action_id="1865862") has completed.
# Your task (action_id="1865863") has started.
# Your task (action_id="1865863") has completed.
# Your task (action_id="1865864") has completed.
# Your task (action_id="1865865") has completed.
# Your task (action_id="1865866") has completed.
# Your task (action_id="1865867") has completed.
# Your task (action_id="1865868") has started.
# Your task (action_id="1865868") has completed.
# Your task (action_id="1865869") has completed.
# Your task (action_id="1865870") has completed.
# Your task (action_id="1865871") has completed.
# Your task (action_id="1865872") has completed.
# Your task (action_id="1865873") has started.
# Your task (action_id="1865873") has completed.
# Your task (action_id="1865874") has completed.
# Your task (action_id="1865875") has completed.
# Your task (action_id="1865876") has completed.
# Your task (action_id="1865877") has completed.
# Your task (action_id="1865878") has started.
# Your task (action_id="1865878") has completed.
# Your task (action_id="1865879") has completed.
# Your task (action_id="1865880") has completed.
# Your task (action_id="1865881") has completed.
# Your task (action_id="1865882") has completed.
# Your task (action_id="1865883") has started.
# Your task (action_id="1865883") has completed.
# Your task (action_id="1865884") has completed.
# Your task (action_id="1865885") has completed.
# Your task (action_id="1865886") has completed.
# Your task (action_id="1865887") has completed.
# Your task (action_id="1865888") has started.
# Your task (action_id="1865888") has completed.
# Your task (action_id="1865889") has completed.
# Your task (action_id="1865890") has completed.
# Your task (action_id="1865891") has completed.
# Your task (action_id="1865892") has completed.
# Your task (action_id="1865893") has started.
# Your task (action_id="1865893") has completed.
# Your task (action_id="1865894") has completed.
# Your task (action_id="1865895") has completed.
# Your task (action_id="1865896") has completed.
# Your task (action_id="1865897") has completed.
# Your task (action_id="1865898") has started.
# Your task (action_id="1865898") has completed.
# Your task (action_id="1865899") has completed.
# Your task (action_id="1865900") has completed.
# Your task (action_id="1865901") has completed.
# Your task (action_id="1865902") has completed.
# Your task (action_id="1865903") has completed.
# Your task (action_id="1865904") has completed.
# Your task (action_id="1865905") has completed.
# Your task (action_id="1865906") has completed.
# Your task (action_id="1865907") has completed.
# Your task (action_id="1865908") has started.
# Your task (action_id="1865908") has completed.
# Your task (action_id="1865909") has completed.
# Your task (action_id="1865910") has completed.
# Your task (action_id="1865911") has completed.
# Your task (action_id="1865912") has completed.
# Your task (action_id="1865913") has completed.
# Your task (action_id="1865914") has completed.
# Your task (action_id="1865915") has completed.
# Your task (action_id="1865916") has completed.
# Your task (action_id="1865917") has completed.
# Your task (action_id="1865918") has completed.
# Your task (action_id="1865919") has completed.
# Your task (action_id="1865920") has completed.
# Your task (action_id="1865921") has completed.
# Your task (action_id="1865922") has completed.
# Your task (action_id="1865923") has started.
# Your task (action_id="1865923") has completed.
# Your task (action_id="1865924") has completed.
# Your task (action_id="1865925") has completed.
# Your task (action_id="1865926") has completed.
# Your task (action_id="1865927") has completed.
# Your task (action_id="1865928") has started.
# Your task (action_id="1865928") has completed.
# Your task (action_id="1865929") has completed.
# Your task (action_id="1865930") has completed.
# Your task (action_id="1865931") has completed.
# Your task (action_id="1865932") has completed.
# Your task (action_id="1865933") has started.
# Your task (action_id="1865933") has completed.
# Your task (action_id="1865934") has completed.
# Your task (action_id="1865935") has completed.
# Your task (action_id="1865936") has completed.
# Your task (action_id="1865937") has completed.
# Your task (action_id="1865938") has started.
# Your task (action_id="1865938") has completed.
# Your task (action_id="1865939") has completed.
# Your task (action_id="1865940") has completed.
# Your task (action_id="1865941") has completed.
# Your task (action_id="1865942") has completed.
# Your task (action_id="1865943") has completed.
# Your task (action_id="1865944") has completed.
# Your task (action_id="1865945") has completed.
# Your task (action_id="1865946") has completed.
# Your task (action_id="1865947") has completed.
# Your task (action_id="1865948") has started.
# Your task (action_id="1865948") has completed.
# Your task (action_id="1865949") has completed.
# Your task (action_id="1865950") has completed.
# Your task (action_id="1865951") has completed.
# Your task (action_id="1865952") has completed.
# Your task (action_id="1865953") has started.
# Your task (action_id="1865953") has completed.
# Your task (action_id="1865954") has completed.
# Your task (action_id="1865955") has completed.
# Your task (action_id="1865956") has completed.
# Your task (action_id="1865957") has completed.
# Your task (action_id="1865958") has started.
# Your task (action_id="1865958") has completed.
# Your task (action_id="1865959") has completed.
# Your task (action_id="1865960") has completed.
# Your task (action_id="1865961") has completed.
# Problem Angle: 0.5077321460347141
# ------------
# Iteration: 9
# ------------
# Your task (action_id="1865962") has completed.
# Your task (action_id="1865963") is queued.
# Your task (action_id="1865963") has completed.
# Your task (action_id="1865964") has completed.
# Your task (action_id="1865965") has completed.
# Your task (action_id="1865966") has completed.
# Your task (action_id="1865967") has completed.
# Your task (action_id="1865968") has completed.
# Your task (action_id="1865969") has started.
# Your task (action_id="1865969") has completed.
# Your task (action_id="1865970") has completed.
# Your task (action_id="1865971") is queued.
# Your task (action_id="1865971") has completed.
# Your task (action_id="1865972") has completed.
# Your task (action_id="1865973") has completed.
# Your task (action_id="1865974") has completed.
# Your task (action_id="1865975") has completed.
# Your task (action_id="1865976") has completed.
# Your task (action_id="1865977") is queued.
# Your task (action_id="1865977") has completed.
# Your task (action_id="1865978") has completed.
# Your task (action_id="1865979") has completed.
# Your task (action_id="1865980") has completed.
# Your task (action_id="1865981") has completed.
# Your task (action_id="1865982") has completed.
# Your task (action_id="1865983") has completed.
# Your task (action_id="1865984") has completed.
# Your task (action_id="1865985") is queued.
# Your task (action_id="1865985") has completed.
# Your task (action_id="1865986") has completed.
# Your task (action_id="1865987") is queued.
# Your task (action_id="1865987") has completed.
# Your task (action_id="1865988") has completed.
# Your task (action_id="1865989") has completed.
# Your task (action_id="1865990") has completed.
# Your task (action_id="1865991") is queued.
# Your task (action_id="1865991") has started.
# Your task (action_id="1865991") has completed.
# Your task (action_id="1865992") has completed.
# Your task (action_id="1865993") has started.
# Your task (action_id="1865993") has completed.
# Your task (action_id="1865994") has completed.
# Your task (action_id="1865995") has completed.
# Your task (action_id="1865996") has completed.
# Your task (action_id="1865997") has completed.
# Your task (action_id="1865998") has started.
# Your task (action_id="1865998") has completed.
# Your task (action_id="1865999") has completed.
# Your task (action_id="1866000") has completed.
# Your task (action_id="1866001") has completed.
# Your task (action_id="1866002") has completed.
# Your task (action_id="1866003") has started.
# Your task (action_id="1866003") has completed.
# Your task (action_id="1866004") has completed.
# Your task (action_id="1866005") has completed.
# Your task (action_id="1866006") has completed.
# Your task (action_id="1866007") has completed.
# Your task (action_id="1866008") has started.
# Your task (action_id="1866008") has completed.
# Your task (action_id="1866009") has completed.
# Your task (action_id="1866010") has completed.
# Your task (action_id="1866011") has completed.
# Your task (action_id="1866012") has completed.
# Your task (action_id="1866013") has started.
# Your task (action_id="1866013") has completed.
# Your task (action_id="1866014") has completed.
# Your task (action_id="1866015") has completed.
# Your task (action_id="1866016") has completed.
# Your task (action_id="1866017") has completed.
# Your task (action_id="1866018") has started.
# Your task (action_id="1866018") has completed.
# Your task (action_id="1866019") has completed.
# Your task (action_id="1866020") has completed.
# Your task (action_id="1866021") has completed.
# Your task (action_id="1866022") has completed.
# Your task (action_id="1866023") has started.
# Your task (action_id="1866023") has completed.
# Your task (action_id="1866024") has completed.
# Your task (action_id="1866025") has completed.
# Your task (action_id="1866026") has completed.
# Your task (action_id="1866027") has completed.
# Your task (action_id="1866028") has started.
# Your task (action_id="1866028") has completed.
# Your task (action_id="1866029") has completed.
# Your task (action_id="1866030") has completed.
# Your task (action_id="1866031") has completed.
# Your task (action_id="1866032") has completed.
# Your task (action_id="1866033") has started.
# Your task (action_id="1866033") has completed.
# Your task (action_id="1866034") has completed.
# Your task (action_id="1866035") has completed.
# Your task (action_id="1866036") has completed.
# Your task (action_id="1866037") has completed.
# Your task (action_id="1866038") has started.
# Your task (action_id="1866038") has completed.
# Your task (action_id="1866039") has completed.
# Your task (action_id="1866040") has completed.
# Your task (action_id="1866041") has completed.
# Your task (action_id="1866042") has completed.
# Your task (action_id="1866043") has started.
# Your task (action_id="1866043") has completed.
# Your task (action_id="1866044") has completed.
# Your task (action_id="1866045") has completed.
# Your task (action_id="1866046") has completed.
# Your task (action_id="1866047") has completed.
# Your task (action_id="1866048") has started.
# Your task (action_id="1866048") has completed.
# Your task (action_id="1866049") has completed.
# Your task (action_id="1866050") has completed.
# Your task (action_id="1866051") has completed.
# Your task (action_id="1866052") has completed.
# Your task (action_id="1866053") has started.
# Your task (action_id="1866053") has completed.
# Your task (action_id="1866054") has completed.
# Your task (action_id="1866055") has completed.
# Your task (action_id="1866056") has completed.
# Your task (action_id="1866057") has completed.
# Your task (action_id="1866058") has started.
# Your task (action_id="1866058") has completed.
# Your task (action_id="1866059") has completed.
# Your task (action_id="1866060") has completed.
# Your task (action_id="1866061") has completed.
# Your task (action_id="1866062") has completed.
# Your task (action_id="1866063") has started.
# Your task (action_id="1866063") has completed.
# Your task (action_id="1866064") has completed.
# Your task (action_id="1866065") has completed.
# Your task (action_id="1866066") has completed.
# Your task (action_id="1866067") has completed.
# Your task (action_id="1866068") has started.
# Your task (action_id="1866068") has completed.
# Your task (action_id="1866069") has completed.
# Your task (action_id="1866070") has completed.
# Your task (action_id="1866071") is queued.
# Your task (action_id="1866071") has completed.
# Your task (action_id="1866072") has completed.
# Your task (action_id="1866073") has started.
# Your task (action_id="1866073") has completed.
# Your task (action_id="1866074") has completed.
# Your task (action_id="1866075") has completed.
# Your task (action_id="1866076") has completed.
# Your task (action_id="1866077") has completed.
# Your task (action_id="1866078") has started.
# Your task (action_id="1866078") has completed.
# Your task (action_id="1866079") has completed.
# Your task (action_id="1866080") has completed.
# Your task (action_id="1866081") has completed.
# Your task (action_id="1866082") has completed.
# Your task (action_id="1866083") has started.
# Your task (action_id="1866083") has completed.
# Your task (action_id="1866084") has completed.
# Your task (action_id="1866085") has completed.
# Your task (action_id="1866086") has completed.
# Your task (action_id="1866087") has completed.
# Your task (action_id="1866088") has completed.
# Your task (action_id="1866089") has completed.
# Your task (action_id="1866090") has completed.
# Your task (action_id="1866091") has completed.
# Problem Angle: 3.173325912716963

# %%
plt.plot(np.linspace(0,2*np.pi,100),new_fidelities)
plt.xlabel("$\\theta$")
plt.ylabel("infidelity")
plt.plot(np.linspace(0,2*np.pi,100),[np.mean(new_fidelities)]*len(np.linspace(0,2*np.pi,100)),'--')
plt.title("Infidelity Plot (Re-optimization)")
# Out:
# Text(0.5, 1.0, 'Infidelity Plot (Re-optimization)')
